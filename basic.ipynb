# %%
##Write a Python program which accepts the radius of a circle from the user and compute the area.
radius = float(input("enter the radius"))
area = 3.14 * radius**2
print("area of circle",area)
# Out:
# enter the radius 34
# area of circle 3629.84

# %%
##Write a Python program to get the volume of a sphere with radius 6. formulae to calculate volume of sphere:  4/3 𝜋 r³
radius =6
volume = 4/3 * 3.14 * radius**3
print("volume of sphere",volume)
# Out:
# volume of sphere 904.3199999999999

# %%
#Write a Python program to calculate the sum of three equal numbers, and the result is the three times of their sum.
num1=int(input("enter the first number"))
num2=int(input("enter the second number"))
num3=int(input("enter the third number"))
if num1==num2==num3:
    add=num1+num2+num3
    result=add*3
    print(result)
else:
    print("three number is not equal")
# Out:
# enter the first number 12
# enter the second number 2
# enter the third number 3
# three number is not equal

# %%
#Write a Python program that will accept the base and height of a triangle and compute the area
#formulae to calculate area of triangle:  1/2 base * height
base = float(input("enter the base"))
height= float(input("enter the height"))
area = 1/2*(base*height)
print(area)
# Out:
# enter the base 2
# enter the height 3
# 3.0

# %%
# Write a Python program to solve (x + y) * (x + y) 
#Test Data : x = 4, y = 3
#Expected Output :   49
x = 4
y = 3
test = (x+y) * (x+y)
print(test)
# Out:
# 49

# %%
# Write a Python program to compute the simple interest of a specified principal amount, rate of interest, and a number of years.
# Test Data : amt = 10000, int = 3.5, years = 7
# formluae= amt* int * years/100
# Expected Output : 
amt = 10000
interest = 3.5
year = 7
si = ((amt * interest * year)/100)
print("simple interest",si)

# %%
# Write a Python program to convert (parse) a string to Float or Integer.
# Test Data : "246.2458"
# Expected Output : 246
data = "246.2458"
data_c=int(float(data))
print(data_c)

# %%
# Write a Python program to calculate the hypotenuse of a right angled triangle.
# Formulae : c2 = a2 + b2,
a = 10
b = 5
c = a**2+b**2
print(c**2)

# %%
# Write a Python program to swap two variables
# Test Data : a = 77, x= 1
# Expected Output : a= 1, x=77
a = 77
x = 1
temp = a
a = x
x = temp
print("a =",a,"x =",x)

# %%
# Write a Python program to calculate the cube of any number which was taken by input
num = int(input("enter the number"))
cube = num**3
print("cube of",num,"is",cube)f
